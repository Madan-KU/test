# %% [markdown]
# # Attrition analysis - 20 min test

# %%
# pip install ydata-profiling --user

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r"C:\Users\Home\Desktop\Madan 2023\Questions\Interview\JLR\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
df_original=df

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
#
#    EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0               1  ...                      Low            80
# 1               2  ...                Very High            80
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0             Bad
# 1                 1                10                      3          Better
#
#   YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0              6                  4                        0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000         1470.0
# mean     36.923810   802.485714          9.192517            1.0
# std       9.135373   403.509100          8.106864            0.0
# min      18.000000   102.000000          1.000000            1.0
# 25%      30.000000   465.000000          2.000000            1.0
# 50%      36.000000   802.000000          7.000000            1.0
# 75%      43.000000  1157.000000         14.000000            1.0
# max      60.000000  1499.000000         29.000000            1.0
#
#        EmployeeNumber   HourlyRate     JobLevel  MonthlyIncome   MonthlyRate  \
# count     1470.000000  1470.000000  1470.000000    1470.000000   1470.000000
# mean      1024.865306    65.891156     2.063946    6502.931293  14313.103401
# std        602.024335    20.329428     1.106940    4707.956783   7117.786044
# ...

# %%
df.describe(include = 'all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome Education EducationField  \
# count                     1470       1470.000000      1470           1470
# unique                       3               NaN         5              6
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.head(2).transpose()
# Out:
#                                         0                       1
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                         College           Below College
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction            Medium                    High
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %%
cat_col = ['Attrition', 'BusinessTravel', 'Department','Education','EducationField','EnvironmentSatisfaction','Gender', 'JobInvolvement','JobRole','JobSatisfaction', 'MaritalStatus', 'Over18','OverTime','PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn import preprocessing
label_encoding = preprocessing.LabelEncoder()
for col in cat_col:
    df[col] = label_encoding.fit_transform(df[col])
    mapping = dict(zip(label_encoding.classes_, label_encoding.transform(label_encoding.classes_)))
    print('Feature', col)
    print('mapping', mapping)
# Out:
# Feature Attrition
# mapping {'No': 0, 'Yes': 1}
# Feature BusinessTravel
# mapping {'Non-Travel': 0, 'Travel_Frequently': 1, 'Travel_Rarely': 2}
# Feature Department
# mapping {'Human Resources': 0, 'Research & Development': 1, 'Sales': 2}
# Feature Education
# mapping {'Bachelor': 0, 'Below College': 1, 'College': 2, 'Doctor': 3, 'Master': 4}
# Feature EducationField
# mapping {'Human Resources': 0, 'Life Sciences': 1, 'Marketing': 2, 'Medical': 3, 'Other': 4, 'Technical Degree': 5}
# Feature EnvironmentSatisfaction
# mapping {'High': 0, 'Low': 1, 'Medium': 2, 'Very High': 3}
# Feature Gender
# mapping {'Female': 0, 'Male': 1}
# Feature JobInvolvement
# mapping {'High': 0, 'Low': 1, 'Medium': 2, 'Very High': 3}
# Feature JobRole
# mapping {'Healthcare Representative': 0, 'Human Resources': 1, 'Laboratory Technician': 2, 'Manager': 3, 'Manufacturing Director': 4, 'Research Director': 5, 'Research Scientist': 6, 'Sales Executive': 7, 'Sales Representative': 8}
# ...

# %%
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.001686   0.077924       -0.024469  -0.004985
# Education                 0.151695  -0.036376       -0.023390   0.027695
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.013460  -0.024461        0.032832   0.006968
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# ...

# %%
corr = df.corr()
plt.figure(figsize=(30, 10))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
df.drop(columns='EmployeeNumber',inplace=True)

# %%
# # Drop unnecessary columns
# data = data.drop(['EmployeeCount', 'Over18', 'StandardHours'], axis=1)

# # One-hot encode categorical variables
# cat_vars = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
# data = pd.get_dummies(data, columns=cat_vars, drop_first=True)

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

data =df
# # Load the data
# data = pd.read_csv(r"C:\Users\Home\Desktop\Madan 2023\X\00.Interview\JLR\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.transpose()
# Out:
#                            0      1     2      3      4      5     6     \
# Age                          41     49    37     33     27     32    59
# Attrition                     1      0     1      0      0      0     0
# BusinessTravel                2      1     2      1      2      1     2
# DailyRate                  1102    279  1373   1392    591   1005  1324
# Department                    2      1     1      1      1      1     1
# DistanceFromHome              1      8     2      3      2      2     3
# Education                     2      1     2      4      1      2     0
# EducationField                1      1     4      1      3      1     3
# EmployeeCount                 1      1     1      1      1      1     1
# EnvironmentSatisfaction       2      0     3      3      1      3     0
# Gender                        0      1     1      0      1      1     0
# HourlyRate                   94     61    92     56     40     79    81
# ...

# %%
data["Attrition"] = LabelEncoder().fit_transform(data['Attrition'])
data["BusinessTravel"] = LabelEncoder().fit_transform(data['BusinessTravel'])
data["Department"] = LabelEncoder().fit_transform(data['Department'])
data["EducationField"] = LabelEncoder().fit_transform(data['EducationField'])
data["Gender"] = LabelEncoder().fit_transform(data['Gender'])
data["JobRole"] = LabelEncoder().fit_transform(data['JobRole'])
data["MaritalStatus"] = LabelEncoder().fit_transform(data['MaritalStatus'])
data["Over18"] = LabelEncoder().fit_transform(data['Over18'])
data["OverTime"] = LabelEncoder().fit_transform(data['OverTime'])
data["Education"] = LabelEncoder().fit_transform(data['Education'])
data["JobInvolvement"] = LabelEncoder().fit_transform(data['JobInvolvement'])
data["JobSatisfaction"] = LabelEncoder().fit_transform(data['JobSatisfaction'])
data["PerformanceRating"] = LabelEncoder().fit_transform(data['PerformanceRating'])
data["RelationshipSatisfaction"] = LabelEncoder().fit_transform(data['RelationshipSatisfaction'])
data["WorkLifeBalance"] = LabelEncoder().fit_transform(data['WorkLifeBalance'])
data["EnvironmentSatisfaction"] = LabelEncoder().fit_transform(data['EnvironmentSatisfaction'])

# %%
X = data.drop(['Attrition'], axis=1)
y = data['Attrition']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# Create a logistic regression model 
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
coefficients = pd.DataFrame(model.coef_, columns=X.columns)

equation = 'y = '
for col in X.columns:
    equation += '{:.5f} * {} + '.format(coefficients[col].values[0], col)
equation += '{:.5f}'.format(model.intercept_[0])
print(equation)
# Out:
# y = -0.01838 * Age + 0.06068 * BusinessTravel + -0.00044 * DailyRate + 0.25344 * Department + 0.04243 * DistanceFromHome + -0.05415 * Education + 0.04776 * EducationField + -0.00002 * EmployeeCount + -0.13333 * EnvironmentSatisfaction + 0.24239 * Gender + 0.00013 * HourlyRate + -0.00012 * JobInvolvement + -0.14493 * JobLevel + 0.01456 * JobRole + -0.18945 * JobSatisfaction + 0.50222 * MaritalStatus + -0.00005 * MonthlyIncome + -0.00001 * MonthlyRate + 0.14629 * NumCompaniesWorked + 0.00000 * Over18 + 1.16789 * OverTime + -0.02161 * PercentSalaryHike + 0.12476 * PerformanceRating + -0.16182 * RelationshipSatisfaction + -0.00151 * StandardHours + -0.32580 * StockOptionLevel + -0.04721 * TotalWorkingYears + -0.09271 * TrainingTimesLastYear + -0.19697 * WorkLifeBalance + 0.02090 * YearsAtCompany + -0.07894 * YearsInCurrentRole + 0.16317 * YearsSinceLastPromotion + -0.08611 * YearsWithCurrManager + -0.00002

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy score:", accuracy)
# Out:
# Accuracy score: 0.8333333333333334

# %% [markdown]
# ------------

# %%
# !pip install imbalanced-learn
# !pip install delayed
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix

# %%
# data.drop(['EmployeeNumber'],axis=1,inplace=True)

# %%
# cols = list(data.columns)
# cols.remove("Attrition")
# sampled,target = SMOTE().fit_resample(data[cols],data["Attrition"])

# %%
# sampled

# %%
# X_train,X_test,Y_train,Y_test = train_test_split(sampled[cols],
#                                                  target,
#                                                  test_size = 0.3,
#                                                  shuffle=True)

# %%
print("Train Feature Size : ",len(X_train))
print("Train Label Size : ",len(y_train))
print("Test Feature Size : ",len(X_test))
print("Test Label Size : ",len(y_test))
# Out:
# Train Feature Size :  1176
# Train Label Size :  1176
# Test Feature Size :  294
# Test Label Size :  294

# %%
logistic_model = LogisticRegression(solver='liblinear',random_state=0).fit(X_train,y_train)
print("Train Accuracy : {:.2f} %".format(accuracy_score(logistic_model.predict(X_train),y_train)))
print("Test Accuracy : {:.2f} %".format(accuracy_score(logistic_model.predict(X_test),y_test)))

cm = confusion_matrix(y_test,logistic_model.predict(X_test))
classes = ["0","1"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=classes)
fig, ax = plt.subplots(figsize=(10,10))
plt.title("Confusion Matrix")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Train Accuracy : 0.86 %
# Test Accuracy : 0.83 %

# %%
random_forest = RandomForestClassifier(n_estimators=590,
                                       random_state=0).fit(X_train,y_train)
print("Train Accuracy : {:.2f} %".format(accuracy_score(random_forest.predict(X_train),y_train)))
print("Test Accuracy : {:.2f} %".format(accuracy_score(random_forest.predict(X_test),y_test)))

cm = confusion_matrix(y_test,random_forest.predict(X_test))
classes = ["0","1"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=classes)
fig, ax = plt.subplots(figsize=(10,10))
plt.title("Confusion Matrix for Radom Forest Classifier")
disp = disp.plot(ax=ax)
plt.show()
# Out:
# Train Accuracy : 1.00 %
# Test Accuracy : 0.82 %

# %%
importances = random_forest.feature_importances_
feature_names = X.columns
for feature_name, importance in zip(feature_names, importances):
    print(f"{feature_name}: {importance}")
# Out:
# Age: 0.061522354286626356
# BusinessTravel: 0.014047417998437735
# DailyRate: 0.06017823125688957
# Department: 0.0136446427571543
# DistanceFromHome: 0.052046053817586056
# Education: 0.018387286749014273
# EducationField: 0.024941723053532806
# EmployeeCount: 0.0
# EnvironmentSatisfaction: 0.023628040984904546
# Gender: 0.010791410411600607
# HourlyRate: 0.049488301036274426
# JobInvolvement: 0.016152497619028833
# JobLevel: 0.025261616700982842
# JobRole: 0.03331606899919738
# JobSatisfaction: 0.02272619399936698
# MaritalStatus: 0.020965045817043372
# MonthlyIncome: 0.08898050938992466
# MonthlyRate: 0.05133229004479901
# NumCompaniesWorked: 0.03485920265637148
# Over18: 0.0
# OverTime: 0.048548872813879596
# PercentSalaryHike: 0.03653690733701451
# PerformanceRating: 0.005307465884627734
# RelationshipSatisfaction: 0.020479806667274277
# StandardHours: 0.0
# StockOptionLevel: 0.02492275638587705
# TotalWorkingYears: 0.05774547489543766
# ...

# %%
import pandas as pd

importances = random_forest.feature_importances_
feature_names = X.columns

dfx = pd.DataFrame({"Feature Name": feature_names, "Importance": importances})
dfx = dfx.sort_values(by="Importance", ascending=False).reset_index(drop=True)
print(dfx)
# Out:
#                 Feature Name  Importance
# 0              MonthlyIncome    0.088981
# 1                        Age    0.061522
# 2                  DailyRate    0.060178
# 3          TotalWorkingYears    0.057745
# 4           DistanceFromHome    0.052046
# 5                MonthlyRate    0.051332
# 6                 HourlyRate    0.049488
# 7                   OverTime    0.048549
# 8             YearsAtCompany    0.042604
# 9          PercentSalaryHike    0.036537
# 10        NumCompaniesWorked    0.034859
# 11                   JobRole    0.033316
# 12      YearsWithCurrManager    0.032544
# 13   YearsSinceLastPromotion    0.029225
# 14        YearsInCurrentRole    0.028596
# 15     TrainingTimesLastYear    0.025864
# 16           WorkLifeBalance    0.025358
# 17                  JobLevel    0.025262
# 18            EducationField    0.024942
# 19          StockOptionLevel    0.024923
# 20   EnvironmentSatisfaction    0.023628
# 21           JobSatisfaction    0.022726
# ...

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
# import matplotlib.pyplot as plt


# random_forest = RandomForestClassifier(n_estimators=590, random_state=0).fit(X_train,y_train)

# train_accuracy = accuracy_score(random_forest.predict(X_train),y_train)
# test_accuracy = accuracy_score(random_forest.predict(X_test),y_test)
# print("Train Accuracy : {:.2f} %".format(train_accuracy * 100))
# print("Test Accuracy : {:.2f} %".format(test_accuracy * 100))

# cm = confusion_matrix(y_test,random_forest.predict(X_test))
# classes = ["0","1"]
# disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
# fig, ax = plt.subplots(figsize=(10,10))
# plt.title("Confusion Matrix for Random Forest Classifier")
# disp = disp.plot(ax=ax)
# plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
precision = precision_score(y_test,random_forest.predict(X_test))
recall = recall_score(y_test,random_forest.predict(X_test))
f1 = f1_score(y_test,random_forest.predict(X_test))
print("Precision : {:.2f}".format(precision))
print("Recall : {:.2f}".format(recall))
print("F1 Score : {:.2f}".format(f1))
# Out:
# Precision : 0.57
# Recall : 0.08
# F1 Score : 0.13

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(random_forest, X_train, y_train, cv=5)
print("Cross Validation Scores : {}".format(cv_scores))
print("Mean Cross Validation Score : {:.2f}".format(cv_scores.mean()))
# Out:
# Cross Validation Scores : [0.86864407 0.87659574 0.83829787 0.86382979 0.86382979]
# Mean Cross Validation Score : 0.86

# %%
# from sklearn.model_selection import GridSearchCV
# param_grid = {'n_estimators': [100, 300, 500, 800, 1000],
#               'max_features': [ 'sqrt', 'log2'],
#               'max_depth' : [4,5,6,7,8],
#               'criterion' :['gini', 'entropy']}
# grid_search = GridSearchCV(estimator = random_forest, param_grid = param_grid, cv = 5)
# grid_search.fit(X_train, y_train)
# best_params = grid_search.best_params_
# print("Best Parameters : {}".format(best_params))

# %%
# Best Parameters : {'criterion': 'gini', 'max_depth': 7, 'max_features': 'auto', 'n_estimators': 100}

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# Create the random forest classifier with the best parameters
random_forest = RandomForestClassifier(criterion='gini', max_depth=7, max_features='auto', n_estimators=100)

# Fit the model to your data
random_forest.fit(X_train, y_train)

# Predict on the training and test sets
y_train_pred = random_forest.predict(X_train)
y_test_pred = random_forest.predict(X_test)

# Calculate the accuracy scores
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Print the accuracy scores
print("Train Accuracy : {:.2f} %".format(train_accuracy*100))
print("Test Accuracy : {:.2f} %".format(test_accuracy*100))

# Calculate the confusion matrix for the test set
confusion_mat = confusion_matrix(y_test, y_test_pred)

# Plot the confusion matrix
import seaborn as sns
sns.heatmap(confusion_mat, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Train Accuracy : 91.16 %
# Test Accuracy : 82.31 %

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=7, max_features='sqrt')


num_features = 10


rfe = RFE(estimator=random_forest, n_features_to_select=num_features)


rfe.fit(X_train, y_train)


selected_features = X_train.columns[rfe.support_]
print("Selected Features: ", selected_features)


random_forest.fit(X_train[selected_features], y_train)
train_accuracy = random_forest.score(X_train[selected_features], y_train)
test_accuracy = random_forest.score(X_test[selected_features], y_test)
print("Train Accuracy : {:.2f} %".format(train_accuracy*100))
print("Test Accuracy : {:.2f} %".format(test_accuracy*100))

# Confusion Matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

y_pred = random_forest.predict(X_test[selected_features])
cm = confusion_matrix(y_test, y_pred)
classes = ["0", "1"]
plt.figure(figsize=(8,8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=classes, yticklabels=classes)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Selected Features:  Index(['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'JobRole',
#        'MonthlyIncome', 'MonthlyRate', 'OverTime', 'TotalWorkingYears',
#        'YearsAtCompany'],
#       dtype='object')
# Train Accuracy : 91.41 %
# Test Accuracy : 80.95 %

# %%
import matplotlib.pyplot as plt

importances = random_forest.feature_importances_
feature_names = list(X_train.columns)

feature_importances = dict(zip(feature_names, importances))

sorted_feature_importances = sorted(feature_importances.items(), key=lambda x: x[1], reverse=True)

top_n = 10  #n Features

plt.bar(range(top_n), [importance for _, importance in sorted_feature_importances[:top_n]])
plt.xticks(range(top_n), [feature for feature, _ in sorted_feature_importances[:top_n]], rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance Score")
plt.title("Top {} Feature Importance Scores".format(top_n))
plt.show()

# %%
# pip install shap

# %%
import shap

explainer = shap.TreeExplainer(random_forest)

shap_values = explainer.shap_values(X_test)


shap.summary_plot(shap_values[1], X_test)

# # Plot dependence plots
# for feature in X_test.columns:
#     shap.dependence_plot(feature, shap_values[1], X_test)

# %% [markdown]
# ------

# %%
# pip install lazypredict

# %%
# import pandas as pd
# import numpy as np
# from sklearn.datasets import load_breast_cancer
# from sklearn.model_selection import train_test_split
# from lazypredict.Supervised import LazyClassifier

# clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# print(models)
